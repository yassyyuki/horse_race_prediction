# %% [markdown]
# # ライブラリのインポート

# %%
import sqlite3
import pandas as pd

# %% [markdown]
# # まとめ

# %%
# DBの作成・接続
def get_and_create_connect_db(dbname='KEIBA.db'):
    conn = sqlite3.connect(dbname)
    return conn

# csvからテーブルの作成・追加
def create_or_insert_table_by_csv(dbname, csv_file, table_name='sample'):
    df = pd.read_csv(csv_file, index_col=0)
    conn = get_and_create_connect_db(dbname)
    cur = conn.cursor()
    df.to_sql(table_name, conn, if_exists='append')
    cur.close()
    conn.close()
    
# DataFrameからテーブルの作成・追加
def create_or_insert_table_by_df(dbname, df, table_name='sample'):
    conn = get_and_create_connect_db(dbname)
    cur = conn.cursor()
    df.to_sql(table_name, conn, if_exists='append')
    cur.close()
    conn.close()

# DBからクエリでデータ抽出
def get_df_by_query(dbname, query='SELECT * FROM sample'):
    conn = get_and_create_connect_db(dbname)
    cur = conn.cursor()
    df = pd.read_sql(query, conn)
    cur.close()
    conn.close()
    return df

# %% [markdown]
# # メソッドの動作確認

# %%
conn = get_and_create_connect_db(dbname='hogehoge.db')

# %%
csv_file = 'sample.csv'

# %%
create_or_insert_table_by_csv(dbname, csv_file, table_name='hoge')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 create_or_insert_table_by_csv(dbname, csv_file, table_name='hoge')
#
# NameError: name 'dbname' is not defined

# %%
df = pd.read_csv("sample2.csv", index_col=0)
create_or_insert_table_by_df(dbname, df, 'hoge')

# %%
get_df_by_query(dbname, 'select * from hoge')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_df_by_query(dbname, 'select * from hoge')
#
# NameError: name 'dbname' is not defined

# %% [markdown]
# # メソッド化する前の動作確認

# %% [markdown]
# ## DBの作成（存在していたら接続）

# %%
# KEIBA.dbを作成する
dbname = 'KEIBA.db'
conn = sqlite3.connect(dbname)

# データベースへのコネクションを閉じる。(必須)
conn.close()

# %% [markdown]
# ## テーブルの作成

# %%
conn = sqlite3.connect(dbname)
# sqliteを操作するカーソルオブジェクトを作成
cur = conn.cursor()

# テーブルの作成（racesというテーブルを作成する例）
cur.execute(
    'CREATE TABLE races(id INTEGER PRIMARY KEY AUTOINCREMENT, name STRING)'
)

# データベースへコミット。これで変更が反映される。
conn.commit()
conn.close()

# %% [markdown]
# ## csvからテーブルの作成

# %%
url = 'https://db.netkeiba.com/race/202205050301/'
dfs = pd.read_html(url)
dfs[0].to_csv('sample.csv')

# %%
# csvには、1列目にyear, 2列目にmonth, 3列目にdayが入っているとする。
df = pd.read_csv("sample.csv", index_col=0)

# カラム名（列ラベル）を作成。csv file内にcolumn名がある場合は、下記は不要
# pandasが自動で1行目をカラム名として認識してくれる。
# df.columns = ['year', 'month', 'day']

conn = sqlite3.connect(dbname)
cur = conn.cursor()

# if_existsで、もしすでにexpenseが存在していたら、書き換えるように指示
df.to_sql('sample', conn, if_exists='append')

cur.close()
conn.close()

# %% [markdown]
# ## DBからpandasで読み取る

# %%
conn = sqlite3.connect(dbname)
cur = conn.cursor()

# dbをpandasで読み出す。
df = pd.read_sql('SELECT * FROM sample', conn)

cur.close()
conn.close()

# %%
df.head()
# Out:
#    index  着 順  枠 番  馬 番         馬名  性齢  斤量    騎手     タイム     着差    単勝  人 気  \
# 0      0    1    2    3   ミラクルキャッツ  牝2  54   レーン  1:39.8   None   3.6    2
# 1      1    2    6   11  ニシノパプルブリリ  牝2  54  津村明秀  1:40.0  1.1/4  85.1   10
# 2      2    3    8   16      リリックス  牝2  54  松岡正海  1:40.8      5  10.8    5
# 3      3    4    4    8     ラピッドベル  牝2  54  戸崎圭太  1:41.0  1.1/4   2.8    1
# 4      4    5    8   15      エテルネル  牝2  54  石川裕紀  1:41.7      4   5.1    3
#
#        馬体重       調教師
# 0  456(+2)   [東] 堀宣行
# 1   460(0)  [東] 矢野英一
# 2  484(-4)  [東] 蛯名正義
# 3  496(-8)  [西] 牧浦充徳
# 4  462(-4)  [東] 池上昌和

# %% [markdown]
# ## DBからSQLでデータを抽出

# %%
conn = sqlite3.connect(dbname)
cur = conn.cursor()
select_sql = 'SELECT * FROM sample'
cur.execute(select_sql)
data = cur.fetchall()

# %%
# DataFrame
columns = [s[0] for s in cur.description]
df = pd.DataFrame(data, columns=columns)
cur.close()
conn.close()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   16 non-null     int64
#  1   着 順     16 non-null     int64
#  2   枠 番     16 non-null     int64
#  3   馬 番     16 non-null     int64
#  4   馬名      16 non-null     object
#  5   性齢      16 non-null     object
#  6   斤量      16 non-null     int64
#  7   騎手      16 non-null     object
#  8   タイム     16 non-null     object
#  9   着差      15 non-null     object
#  10  単勝      16 non-null     float64
#  11  人 気     16 non-null     int64
#  12  馬体重     16 non-null     object
#  13  調教師     16 non-null     object
# dtypes: float64(1), int64(6), object(7)
# memory usage: 1.9+ KB

# %% [markdown]
# ## データの追加

# %%
url = 'https://db.netkeiba.com/race/202205050302/'
dfs = pd.read_html(url)
dfs[0].to_csv('sample2.csv')

# %%
# csvには、1列目にyear, 2列目にmonth, 3列目にdayが入っているとする。
df = pd.read_csv("sample2.csv", index_col=0)

# カラム名（列ラベル）を作成。csv file内にcolumn名がある場合は、下記は不要
# pandasが自動で1行目をカラム名として認識してくれる。
# df.columns = ['year', 'month', 'day']

conn = sqlite3.connect(dbname)
cur = conn.cursor()

# if_existsで、もしすでに存在していたら追加するように指示
df.to_sql('sample', conn, if_exists='append')

cur.close()
conn.close()

# %%
conn = sqlite3.connect(dbname)
cur = conn.cursor()
select_sql = 'SELECT * FROM sample'
cur.execute(select_sql)
data = cur.fetchall()
df = pd.DataFrame(data, columns=columns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   28 non-null     int64
#  1   着 順     28 non-null     int64
#  2   枠 番     28 non-null     int64
#  3   馬 番     28 non-null     int64
#  4   馬名      28 non-null     object
#  5   性齢      28 non-null     object
#  6   斤量      28 non-null     int64
#  7   騎手      28 non-null     object
#  8   タイム     28 non-null     object
#  9   着差      26 non-null     object
#  10  単勝      28 non-null     float64
#  11  人 気     28 non-null     int64
#  12  馬体重     28 non-null     object
#  13  調教師     28 non-null     object
# dtypes: float64(1), int64(6), object(7)
# memory usage: 3.2+ KB

# %% [markdown]
# # データの確認

# %%
df
# Out:
#     index  着 順  枠 番  馬 番         馬名  性齢  斤量    騎手     タイム     着差     単勝  人 気  \
# 0       0    1    2    3   ミラクルキャッツ  牝2  54   レーン  1:39.8   None    3.6    2
# 1       1    2    6   11  ニシノパプルブリリ  牝2  54  津村明秀  1:40.0  1.1/4   85.1   10
# 2       2    3    8   16      リリックス  牝2  54  松岡正海  1:40.8      5   10.8    5
# 3       3    4    4    8     ラピッドベル  牝2  54  戸崎圭太  1:41.0  1.1/4    2.8    1
# 4       4    5    8   15      エテルネル  牝2  54  石川裕紀  1:41.7      4    5.1    3
# 5       5    6    3    6        ヒラリ  牝2  54  ルメール  1:41.8     クビ    7.9    4
# 6       6    7    5    9      ミズカガミ  牝2  53  永野猛蔵  1:41.9    1/2  143.9   13
# 7       7    8    5   10        リーア  牝2  54  横山和生  1:41.9    アタマ   60.1    9
# 8       8    9    1    2   ポポラーレウーノ  牝2  51  西塚洸二  1:41.9     クビ   21.6    6
# 9       9   10    3    5     ラディーヴァ  牝2  54  木幡巧也  1:42.0    1/2  306.9   15
# 10     10   11    7   13        リヨン  牝2  54  丸田恭介  1:42.1    1/2   49.9    7
# 11     11   12    4    7   ワラッテユルシテ  牝2  54  坂井瑠星  1:42.2     クビ  113.7   12
# 12     12   13    6   12    アースジェール  牝2  54  内田博幸  1:42.5  1.3/4  196.9   14
# 13     13   14    7   14  ユーメイドマイデイ  牝2  54  江田照男  1:42.9  2.1/2   93.6   11
# 14     14   15    1    1   タイセイアリオス  牝2  54  西村淳也  1:43.4      3  346.4   16
# 15     15   16    2    4    ワタシハマジョ  牝2  54  菅原明良  1:44.3      5   53.9    8
# 16      0    1    6    8    ニシノライコウ  牡2  54  永野猛蔵  1:33.6   None   30.2    6
# 17      1    2    6    7  シャドウフューリー  牡2  55   ムーア  1:33.8  1.1/4    3.0    2
# 18      2    3    1    1     アンスリウム  牝2  54  ルメール  1:34.5      4    8.1    4
# 19      3    4    2    2  レッドバレンティア  牡2  55  福永祐一  1:34.5     クビ    2.2    1
# 20      4    5    7    9  シエロエスティーボ  牡2  55  マーカン  1:34.7  1.1/2    5.4    3
# 21      5    6    5    6   コンスピキュアス  牡2  55  横山和生  1:34.7    アタマ   20.6    5
# 22      6    7    8   11       ウェンス  牡2  55  菅原明良  1:35.2  2.1/2   68.0    7
# 23      7    8    8   12      シャコンヌ  牡2  55   ドイル  1:35.3  1.1/4  154.0    8
# 24      8    9    7   10   クリスプブリーズ  牡2  55  木幡巧也  1:35.3    アタマ  312.3    9
# 25      9   10    3    3      イブシギン  牡2  55  水口優也  1:35.5  1.1/4  315.4   10
# 26     10   11    5    5    ニシノセイラン  牡2  55  野中悠太  1:35.6     クビ  334.1   11
# 27     11   12    4    4    レッドカメリア  牝2  54  武士沢友  1:35.9      2  459.5   12
#
#          馬体重       調教師
# 0    456(+2)   [東] 堀宣行
# 1     460(0)  [東] 矢野英一
# 2    484(-4)  [東] 蛯名正義
# 3    496(-8)  [西] 牧浦充徳
# 4    462(-4)  [東] 池上昌和
# 5    460(+4)  [西] 武幸四郎
# 6    442(-2)   [東] 土田稔
# 7    444(+2)  [東] 小西一男
# 8   472(+12)  [東] 竹内正洋
# 9    458(-2)  [東] 武市康男
# 10   466(+4)  [東] 伊藤大士
# 11   506(+4)  [東] 佐藤吉勝
# 12   454(-8)  [東] 加藤士津
# 13   422(-2)  [東] 大江原哲
# 14   424(-4)  [東] 青木孝文
# 15  458(+12)  [東] 矢野英一
# 16   484(+6)  [東] 古賀慎明
# 17  464(+12)  [西] 杉山晴紀
# 18   480(-4)  [東] 加藤征弘
# 19   440(+6)  [東] 手塚貴久
# 20  478(-10)  [東] 小島茂之
# 21   452(+4)   [東] 栗田徹
# 22   442(+6)  [東] 杉浦宏昭
# 23   444(+6)  [東] 小手川準
# 24   498(-2)  [東] 菊川正達
# 25   418(-4)  [東] 岩戸孝樹
# 26    440(0)  [東] 根本康広
# 27   428(-4)  [東] 加藤和宏
